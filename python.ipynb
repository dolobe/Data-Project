# %%
import pandas as pd
from pymongo import MongoClient

mongo_url = "mongodb+srv://GroupeYboost:Yboost123456@dataspotifyml.j8nw7.mongodb.net/"
db_name = "spotify_db"
collection_name = "artists"

client = MongoClient(mongo_url)
db = client[db_name]
collection = db[collection_name]

data = list(collection.find())
df = pd.DataFrame(data)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      10 db = client[db_name]
#      11 collection = db[collection_name]
# ---> 13 data = list(collection.find())
#      14 df = pd.DataFrame(data)
#      16 print(df.head())
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\cursor.py:1262, in Cursor.next(self)
#    1260 if self.__empty:
#    1261     raise StopIteration
# -> 1262 if len(self.__data) or self._refresh():
#    1263     return self.__data.popleft()
#    1264 else:
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\cursor.py:1202, in Cursor._refresh(self)
#    1187     # Exhaust cursors don't send getMore messages.
#    1188     g = self._getmore_class(
#    1189         self.__dbname,
#    1190         self.__collname,
#    (...)
#    1200         self.__comment,
#    1201     )
# -> 1202     self.__send_message(g)
#    1204 return len(self.__data)
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\mongo_client.py:1388, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1383     operation.reset()  # Reset op in case of retry.
#    1384     return server.run_operation(
#    1385         conn, operation, read_preference, self._event_listeners, unpack_res
#    1386     )
# -> 1388 return self._retryable_read(
#    1389     _cmd,
#    1390     operation.read_preference,
#    1391     operation.session,
#    1392     address=address,
#    1393     retryable=isinstance(operation, message._Query),
#    1394 )
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\mongo_client.py:1535, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1533             assert last_error is not None
#    1534             raise last_error
# -> 1535         return func(session, server, conn, read_pref)
#    1536 except ServerSelectionTimeoutError:
#    1537     if retrying:
#    1538         # The application may think the write was never attempted
#    1539         # if we raise ServerSelectionTimeoutError on the retry
#    1540         # attempt. Raise the original exception instead.
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\mongo_client.py:1384, in MongoClient._run_operation.<locals>._cmd(session, server, conn, read_preference)
#    1377 def _cmd(
#    1378     session: Optional[ClientSession],
#    1379     server: Server,
#    1380     conn: Connection,
#    1381     read_preference: _ServerMode,
#    1382 ) -> Response:
#    1383     operation.reset()  # Reset op in case of retry.
# -> 1384     return server.run_operation(
#    1385         conn, operation, read_preference, self._event_listeners, unpack_res
#    1386     )
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\helpers.py:315, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     312 from pymongo.pool import Connection
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except OperationFailure as exc:
#     317     if no_reauth:
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\server.py:155, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     153 else:
#     154     conn.send_message(data, max_doc_size)
# --> 155     reply = conn.receive_message(request_id)
#     157 # Unpack and check for command errors.
#     158 if use_cmd:
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\pool.py:986, in Connection.receive_message(self, request_id)
#     984     return receive_message(self, request_id, self.max_message_size)
#     985 except BaseException as error:
# --> 986     self._raise_connection_failure(error)
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\pool.py:984, in Connection.receive_message(self, request_id)
#     979 """Receive a raw BSON message or raise ConnectionFailure.
#     980
#     981 If any exception is raised, the socket is closed.
#     982 """
#     983 try:
# --> 984     return receive_message(self, request_id, self.max_message_size)
#     985 except BaseException as error:
#     986     self._raise_connection_failure(error)
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\network.py:267, in receive_message(conn, request_id, max_message_size)
#     265     data = decompress(_receive_data_on_socket(conn, length - 25, deadline), compressor_id)
#     266 else:
# --> 267     data = _receive_data_on_socket(conn, length - 16, deadline)
#     269 try:
#     270     unpack_reply = _UNPACK_REPLY[op_code]
#
# File c:\Users\rakot\B2-INFO\Ruse\Data-Spotify-ML-\venv\Lib\site-packages\pymongo\network.py:328, in _receive_data_on_socket(conn, length, deadline)
#     326     if _csot.get_timeout() and deadline is not None:
#     327         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 328     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     329 except BLOCKING_IO_ERRORS:
#     330     raise socket.timeout("timed out")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
